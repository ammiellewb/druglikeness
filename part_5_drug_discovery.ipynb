# %% [markdown]
# <a href="https://colab.research.google.com/github/ammiellewb/druglikeness/blob/main/part_5_drug_discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# downloading lazypredict to quickly build classification and regression models
! pip install lazypredict
# Out:
# ...
#      |████████████████████████████████| 25.9MB 166kB/s
# ...
#      |████████████████████████████████| 276kB 33.0MB/s
# ...
#      |████████████████████████████████| 14.5MB 256kB/s
# ...
#      |████████████████████████████████| 127.6MB 88kB/s
# ...
#      |████████████████████████████████| 6.8MB 27.8MB/s
# ...
#      |████████████████████████████████| 10.1MB 46.6MB/s
# ...
#      |████████████████████████████████| 256kB 44.2MB/s
# ...
#      |████████████████████████████████| 1.2MB 44.7MB/s
# ...
#      |████████████████████████████████| 307kB 54.3MB/s
# ...
#      |████████████████████████████████| 81kB 6.3MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=b0bbba6e8e03186c3912061c7570ed44bc683b9f974b03a24aad0d802808a592
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built PyYAML
# ERROR: tensorflow 2.4.1 has requirement numpy~=1.19.2, but you'll have numpy 1.19.1 which is incompatible.
# ...

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %%
df5 = pd.read_csv('/content/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')
df5 = df5.dropna(axis=0)
df5
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880  pIC50
# 0           1.00        1.00        1.00  ...          0.00          0.00   6.12
# 1           1.00        1.00        1.00  ...          0.00          0.00   7.00
# 2           1.00        1.00        1.00  ...          0.00          0.00   4.30
# 3           1.00        1.00        0.00  ...          0.00          0.00   6.52
# 4           1.00        1.00        0.00  ...          0.00          0.00   6.10
# ...          ...         ...         ...  ...           ...           ...    ...
# 4690        1.00        1.00        1.00  ...          0.00          0.00   5.61
# 4691        1.00        1.00        1.00  ...          0.00          0.00   5.60
# 4692        1.00        1.00        1.00  ...          0.00          0.00   5.42
# 4693        1.00        1.00        1.00  ...          0.00          0.00   5.46
# 4694        1.00        1.00        1.00  ...          0.00          0.00   5.56
#
# ...

# %%
# dropping pIC50 column for X matrix
X = df5.drop('pIC50', axis=1)
Y = df5.pIC50

# %%
# removing low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8*(1-8)))
X = selection.fit_transform(X)

# %%
# splitting the data for training and testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2)

# %%
# defining and building the lazyclassifier
clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
train, test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [06:03<00:00,  8.64s/it]

# %%
# displaying the performance table of the training set (80%)
train
# Out:
#                                             Adjusted R-Squared  ...  Time Taken
# Model                                                           ...
# HistGradientBoostingRegressor                            -6.57  ...       21.99
# LGBMRegressor                                            -6.57  ...        1.41
# SVR                                                      -7.07  ...       24.43
# KNeighborsRegressor                                      -7.07  ...        7.01
# NuSVR                                                    -7.18  ...       18.78
# RandomForestRegressor                                    -7.26  ...       18.51
# XGBRegressor                                             -7.41  ...       11.04
# BaggingRegressor                                         -7.66  ...        2.17
# GradientBoostingRegressor                                -8.34  ...       10.62
# ElasticNetCV                                             -8.63  ...       49.56
# ...

# %%
# displaying the performance table of the test set (20%)
test
# Out:
#                                             Adjusted R-Squared  ...  Time Taken
# Model                                                           ...
# HistGradientBoostingRegressor                            -6.57  ...       21.99
# LGBMRegressor                                            -6.57  ...        1.41
# SVR                                                      -7.07  ...       24.43
# KNeighborsRegressor                                      -7.07  ...        7.01
# NuSVR                                                    -7.18  ...       18.78
# RandomForestRegressor                                    -7.26  ...       18.51
# XGBRegressor                                             -7.41  ...       11.04
# BaggingRegressor                                         -7.66  ...        2.17
# GradientBoostingRegressor                                -8.34  ...       10.62
# ElasticNetCV                                             -8.63  ...       49.56
# ...

# %%
# plotting!!
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# displaying a bar plot of R-squared values
plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=train.index, x="R-Squared", data=train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# displaying a bar plot of RMSE values
plt.figure(figsize=(5, 10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=train.index, x='RMSE', data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# displaying a bar plot of calculation time
plt.figure(figsize=(5, 10))
sns.set_theme(style='whitegrid')
ax = sns.barplot(y=train.index, x='Time Taken', data=train)
ax.set(xlim=(0, 50))
# Out:
# [(0.0, 50.0)]
